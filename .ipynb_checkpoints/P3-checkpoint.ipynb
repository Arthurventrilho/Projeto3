# %% [markdown]
# # Projeto 3 - Google Play Store Apps
#
# Ciências dos Dados
#
# **1.Arthur Ventrilho**
#
# **2.Gabriel Zanetti**
#
# **3.Roger Pina**

# %% [markdown]
# ## Pergunta
# Neste dataset, onde há poucas variáveis e um bom número delas é qualitativa, qual é a saída que se pode prever com um maior grau de acuracia a partir de modelos de regressão?

# %% [markdown]
# ### Etapa 1: Importando e colocando as funções que serão utilizadas

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math
import mpmath
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.stats import norm, probplot, t
from sklearn.model_selection import train_test_split

# %%
# Função utilitária para fazer a regressão com constante adicionada
def regress_cp(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

def regress(X,Y):
    model = sm.OLS(Y,X)
    results = model.fit()
    return results

# %%
#Função que transforma colunas categóricas em colunas quantitativas
def dummify(data, column_name):
    """
        Converte a coluna column_name em dummies / one-hot e as adiciona ao dataframe
        retorna uma copia do  df original *sem* a coluna que foi dummified
    """
    df = data.copy()
    # Nota: se você for um econometrista, pode se interessar por usar a opção dropFirst = True na get_dummies
    df2 = pd.concat([df.drop(column_name, axis=1), pd.get_dummies(data[column_name], prefix=column_name + "_")], axis=1)
    return df2

# %%
#Rating como saída
data = pd.read_csv('googleplaystore.csv')
data = data.dropna(axis=0)

#Install como saída
data_ = pd.read_csv('googleplaystore.csv')
data_ = data_.dropna(axis=0)

# %% [markdown]
# ### Etapa 2: Arrumando os dados

# %%
del data['Genres']
del data['Last Updated']
del data['Current Ver']
del data['Android Ver']

del data_['Genres']
del data_['Last Updated']
del data_['Current Ver']
del data_['Android Ver']

# %%
#Tranformando Installs em quant
deletar = ['+', ',']
Installs_novo = []
Installs_novo_ = []

for frase in data['Installs']:
    for c in deletar:
        frase = frase.replace(c , "")
    Installs_novo.append(frase)
Installs_novo
data['Installs'] = pd.Series((Installs_novo), index = data.index)

for frase in data_['Installs']:
    for c in deletar:
        frase = frase.replace(c , "")
    Installs_novo_.append(frase)
Installs_novo_
data_['Installs'] = pd.Series((Installs_novo_), index = data_.index)

# %%
#Deixando Price em quant
deletar = ['$']
Price_novo = []
Price_novo_ = []

for frase in data['Price']:
    for c in deletar:
        frase = frase.replace(c , "")
    Price_novo.append(frase)
data['Price'] = pd.Series((Price_novo), index = data.index)

for frase in data_['Price']:
    for c in deletar:
        frase = frase.replace(c , "")
    Price_novo_.append(frase)
data_['Price'] = pd.Series((Price_novo_), index = data_.index)

# %%
data = data.drop(data[data.Size == "Varies with device"].index)
data_ = data_.drop(data_[data_.Size == "Varies with device"].index)

def retira_letras(DF, coluna):
    listaA = []
        
    if coluna == 'Size':
        for linha in DF[coluna]:
            if linha[-1] == 'k':
                listaA.append(int(float(linha[:-1]) * 1000))
            elif linha[-1] == 'M':
                listaA.append(int(float(linha[:-1]) * 1000000))
    DF[coluna] = pd.Series((listaA), index = DF.index)


retira_letras(data, 'Size')
retira_letras(data_, 'Size')

# %%
def transforma_em_numero(DF):
    colunas_int = ['Reviews', 'Size', 'Installs']
    colunas_ft = ['Rating', 'Price']
    
    for coluna in colunas_ft:
        listaft = []
        for linha in DF[coluna]:
            listaft.append(float(linha))
        DF[coluna] = pd.Series((listaft), index = DF.index)
    
    for coluna in colunas_int:
        lista = []
        for linha in DF[coluna]:
            lista.append(int(linha))
        DF[coluna] = pd.Series((lista), index = DF.index)
        
transforma_em_numero(data)
transforma_em_numero(data_)

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# 30                        Pink Silver Bow Keyboard Theme       ART_AND_DESIGN
# 31                                     Art Drawing Ideas       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10792                             Soccer Clubs Logo Quiz                 GAME
# 10793                                          Sid Story                 GAME
# 10795                           Reindeer VPN - Proxy VPN                TOOLS
# 10796   Inf VPN - Global Proxy & Unlimited Free WIFI VPN                TOOLS
# 10797                              Fuel Rewards® program            LIFESTYLE
# 10799                                     Fr Daoud Lamei               SOCIAL
# 10800                                          FR Roster                TOOLS
# 10801                                Fr Ignacio Outreach               FAMILY
# 10802                                FR: My Famous Lover               FAMILY
# 10803                       Fatal Raid - No.1 Mobile FPS                 GAME
# 10804                                       Poker Pro.Fr                 GAME
# 10805                                      Scoreboard FR            LIFESTYLE
# 10809              Castle Clash: RPG War and Strategy FR               FAMILY
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10812                                      Fr Agnel Pune               FAMILY
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10817                               HTC Sense Input - FR                TOOLS
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews      Size  Installs  Type  Price Content Rating
# 0         4.1      159  19000000     10000  Free    0.0       Everyone
# 1         3.9      967  14000000    500000  Free    0.0       Everyone
# 2         4.7    87510   8700000   5000000  Free    0.0       Everyone
# 3         4.5   215644  25000000  50000000  Free    0.0           Teen
# 4         4.3      967   2800000    100000  Free    0.0       Everyone
# 5         4.4      167   5600000     50000  Free    0.0       Everyone
# 6         3.8      178  19000000     50000  Free    0.0       Everyone
# 7         4.1    36815  29000000   1000000  Free    0.0       Everyone
# 8         4.4    13791  33000000   1000000  Free    0.0       Everyone
# 9         4.7      121   3100000     10000  Free    0.0       Everyone
# 10        4.4    13880  28000000   1000000  Free    0.0       Everyone
# 11        4.4     8788  12000000   1000000  Free    0.0       Everyone
# 12        4.2    44829  20000000  10000000  Free    0.0           Teen
# 13        4.6     4326  21000000    100000  Free    0.0       Everyone
# 14        4.4     1518  37000000    100000  Free    0.0       Everyone
# 16        4.7     3632   5500000    500000  Free    0.0       Everyone
# 17        4.5       27  17000000     10000  Free    0.0       Everyone
# 18        4.3   194216  39000000   5000000  Free    0.0       Everyone
# 19        4.6   224399  31000000  10000000  Free    0.0       Everyone
# 20        4.0      450  14000000    100000  Free    0.0       Everyone
# 21        4.1      654  12000000    100000  Free    0.0       Everyone
# 22        4.7     7699   4200000    500000  Free    0.0   Everyone 10+
# 24        4.7      118  23000000     50000  Free    0.0       Everyone
# 25        4.8      192   6000000     10000  Free    0.0       Everyone
# 26        4.7    20260  25000000    500000  Free    0.0       Everyone
# 27        4.1      203   6100000    100000  Free    0.0       Everyone
# 28        3.9      136   4600000     10000  Free    0.0       Everyone
# 29        4.1      223   4200000    100000  Free    0.0       Everyone
# 30        4.2     1120   9200000    100000  Free    0.0       Everyone
# 31        4.1      227   5200000     50000  Free    0.0       Everyone
# ...       ...      ...       ...       ...   ...    ...            ...
# 10792     4.2    21661  16000000   1000000  Free    0.0       Everyone
# 10793     4.4    28510  78000000    500000  Free    0.0           Teen
# 10795     4.2     7339   4000000    100000  Free    0.0       Everyone
# 10796     4.7    61445   7800000   1000000  Free    0.0       Everyone
# 10797     4.6    32433  46000000   1000000  Free    0.0       Everyone
# 10799     4.7     2036   6800000    100000  Free    0.0       Everyone
# 10800     4.1      174  12000000      5000  Free    0.0       Everyone
# 10801     4.9       52  19000000      1000  Free    0.0       Everyone
# 10802     4.0      185  28000000     10000  Free    0.0           Teen
# 10803     4.3    56496  81000000   1000000  Free    0.0           Teen
# 10804     4.2     5442  17000000    100000  Free    0.0           Teen
# 10805     4.3        3  15000000       100  Free    0.0       Everyone
# 10809     4.7   376223  24000000   1000000  Free    0.0       Everyone
# 10810     4.8       19  21000000       100  Free    0.0       Everyone
# 10812     4.1       80  13000000      1000  Free    0.0       Everyone
# 10814     4.0      785  31000000     50000  Free    0.0           Teen
# 10815     4.2     5775   4900000    500000  Free    0.0       Everyone
# 10817     4.0      885   8000000    100000  Free    0.0       Everyone
# 10819     3.3       52   3600000      5000  Free    0.0           Teen
# 10820     5.0       22   8600000      1000  Free    0.0           Teen
# 10827     4.2      117  13000000      5000  Free    0.0       Everyone
# 10828     3.4      291  13000000     10000  Free    0.0       Everyone
# 10829     4.6      603   7400000     10000  Free    0.0       Everyone
# 10830     3.8      881   2300000    100000  Free    0.0       Everyone
# 10832     3.8     1195    582000    100000  Free    0.0       Everyone
# 10833     4.8       44    619000      1000  Free    0.0       Everyone
# 10834     4.0        7   2600000       500  Free    0.0       Everyone
# 10836     4.5       38  53000000      5000  Free    0.0       Everyone
# 10837     5.0        4   3600000       100  Free    0.0       Everyone
# 10840     4.5   398307  19000000  10000000  Free    0.0       Everyone
#
# [7723 rows x 9 columns]

# %%
#Declarando Categórico para a saída Rating
data.Category = data.Category.astype('category')
data.Type = data.Type.astype('category')
data['Content Rating'] = data['Content Rating'].astype('category')

# %%
#Declarando Categórico para a saída Install
data_.Category = data_.Category.astype('category')
data_.Type = data_.Type.astype('category')
data_['Content Rating'] = data_['Content Rating'].astype('category')

# %%
#Declarando Quantitativas
quantitativas = ['Rating', 'Reviews', 'Size', 'Installs', 'Price']

# %% [markdown]
# ### Etapa 3: Rating como saída

# %% [markdown]
# #### 3.1: Regressão Linear somente com as colunas quantitativas

# %%
#Separando a coluna que será a saída
quant = quantitativas.copy()
quant.remove('Rating')

# %%
#Fazendo a regressão com a constante
results = regress_cp(data.loc[:, quant], data.Rating)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     21.74
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):           7.33e-18
# Time:                        18:42:45   Log-Likelihood:                -6221.9
# No. Observations:                7723   AIC:                         1.245e+04
# Df Residuals:                    7718   BIC:                         1.249e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1328      0.009    476.509      0.000       4.116       4.150
# Reviews     1.796e-08   4.31e-09      4.164      0.000     9.5e-09    2.64e-08
# Size        1.577e-09   2.71e-10      5.819      0.000    1.05e-09    2.11e-09
# Installs    3.215e-11   1.58e-10      0.204      0.838   -2.77e-10    3.41e-10
# Price         -0.0006      0.000     -1.667      0.096      -0.001       0.000
# ==============================================================================
# Omnibus:                     2752.071   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11889.252
# Skew:                          -1.708   Prob(JB):                         0.00
# Kurtosis:                       8.028   Cond. No.                     7.28e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.28e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Analisando os dados podemos concluir que os resíduos da nossa regressão linear não seguem uma distribuição normal, isso foi visto através da Prob(Omnibus) e Prob(JB) que foram altas, com isso não podemos confiar no p-value.

# %%
#Justificando o que foi afirmado acima
probplot(results.resid, dist="norm", plot=plt);

# %% [markdown]
# #### 3.2: Tirando a constante da regressão linear

# %%
#Fazendo a regressão sem a constante
results1 = regress(data.loc[:, quant], data.Rating)
results1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     1903.
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):               0.00
# Time:                        18:42:46   Log-Likelihood:                -19409.
# No. Observations:                7723   AIC:                         3.883e+04
# Df Residuals:                    7719   BIC:                         3.885e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Reviews     -1.39e-07   2.37e-08     -5.863      0.000   -1.86e-07   -9.26e-08
# Size        9.065e-08   1.08e-09     83.803      0.000    8.85e-08    9.28e-08
# Installs    3.943e-09   8.68e-10      4.540      0.000    2.24e-09    5.64e-09
# Price          0.0103      0.002      5.276      0.000       0.006       0.014
# ==============================================================================
# Omnibus:                     1439.144   Durbin-Watson:                   0.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2401.111
# Skew:                          -1.258   Prob(JB):                         0.00
# Kurtosis:                       4.063   Cond. No.                     2.97e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Plotando um gráfico a fim de visualizar se é uma distribuição normal ou não
probplot(results1.resid, dist="norm", plot=plt);

# %% [markdown]
# Como podemos notar, essa regressão não faz parte de uma distribuição normal

# %% [markdown]
# #### 3.3: Transformando as colunas categóricas em quantitativas

# %%
#Covertendo Category
cat = dummify(data, "Category")

# %%
#Adicionando 30 colunas a mais no Data Frame
quant.extend(['Category__ART_AND_DESIGN', 'Category__AUTO_AND_VEHICLES','Category__BEAUTY', 'Category__BOOKS_AND_REFERENCE',
       'Category__BUSINESS', 'Category__COMICS', 'Category__COMMUNICATION','Category__DATING', 'Category__EDUCATION', 'Category__ENTERTAINMENT',
       'Category__EVENTS', 'Category__FAMILY', 'Category__FINANCE','Category__FOOD_AND_DRINK', 'Category__GAME',
       'Category__HEALTH_AND_FITNESS', 'Category__HOUSE_AND_HOME','Category__LIBRARIES_AND_DEMO', 'Category__LIFESTYLE',
       'Category__MAPS_AND_NAVIGATION', 'Category__MEDICAL','Category__NEWS_AND_MAGAZINES', 'Category__PARENTING',
       'Category__PERSONALIZATION', 'Category__PHOTOGRAPHY','Category__PRODUCTIVITY', 'Category__SHOPPING', 'Category__SOCIAL',
       'Category__SPORTS', 'Category__TOOLS', 'Category__TRAVEL_AND_LOCAL','Category__VIDEO_PLAYERS', 'Category__WEATHER'])

# %%
#Fazendo a regressão somente com as categóricas da coluna "Category"
results1 = regress(cat.loc[:, quant], cat.Rating)
results1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     8.495
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):           1.75e-43
# Time:                        18:42:47   Log-Likelihood:                -6114.5
# No. Observations:                7723   AIC:                         1.230e+04
# Df Residuals:                    7686   BIC:                         1.256e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Reviews                        1.716e-08   4.29e-09      4.000      0.000    8.75e-09    2.56e-08
# Size                           1.065e-09   2.99e-10      3.563      0.000    4.79e-10    1.65e-09
# Installs                       4.803e-11   1.57e-10      0.306      0.759   -2.59e-10    3.55e-10
# Price                            -0.0005      0.000     -1.494      0.135      -0.001       0.000
# Category__ART_AND_DESIGN          4.3669      0.070     62.028      0.000       4.229       4.505
# Category__AUTO_AND_VEHICLES       4.1244      0.068     60.872      0.000       3.992       4.257
# Category__BEAUTY                  4.2753      0.088     48.508      0.000       4.103       4.448
# Category__BOOKS_AND_REFERENCE     4.3044      0.045     96.039      0.000       4.217       4.392
# Category__BUSINESS                4.1036      0.034    119.215      0.000       4.036       4.171
# Category__COMICS                  4.1164      0.077     53.752      0.000       3.966       4.266
# Category__COMMUNICATION           4.0790      0.037    109.885      0.000       4.006       4.152
# Category__DATING                  3.9379      0.041     95.890      0.000       3.857       4.018
# Category__EDUCATION               4.3640      0.051     84.876      0.000       4.263       4.465
# Category__ENTERTAINMENT           4.1201      0.057     72.523      0.000       4.009       4.231
# Category__EVENTS                  4.4635      0.087     51.332      0.000       4.293       4.634
# Category__FAMILY                  4.1557      0.016    259.049      0.000       4.124       4.187
# Category__FINANCE                 4.0963      0.033    122.432      0.000       4.031       4.162
# Category__FOOD_AND_DRINK          4.0709      0.059     69.170      0.000       3.956       4.186
# Category__GAME                    4.1961      0.022    192.013      0.000       4.153       4.239
# Category__HEALTH_AND_FITNESS      4.1971      0.037    114.764      0.000       4.125       4.269
# Category__HOUSE_AND_HOME          4.1433      0.072     57.762      0.000       4.003       4.284
# Category__LIBRARIES_AND_DEMO      4.1911      0.069     61.049      0.000       4.056       4.326
# Category__LIFESTYLE               4.0803      0.032    125.850      0.000       4.017       4.144
# Category__MAPS_AND_NAVIGATION     3.9944      0.055     72.400      0.000       3.886       4.103
# Category__MEDICAL                 4.1651      0.030    137.341      0.000       4.106       4.225
# Category__NEWS_AND_MAGAZINES      4.1276      0.042     99.381      0.000       4.046       4.209
# Category__PARENTING               4.3244      0.081     53.411      0.000       4.166       4.483
# Category__PERSONALIZATION         4.3089      0.032    133.429      0.000       4.246       4.372
# Category__PHOTOGRAPHY             4.1224      0.035    116.981      0.000       4.053       4.191
# Category__PRODUCTIVITY            4.1265      0.035    117.389      0.000       4.058       4.195
# Category__SHOPPING                4.2048      0.040    104.252      0.000       4.126       4.284
# Category__SOCIAL                  4.2333      0.041    104.177      0.000       4.154       4.313
# Category__SPORTS                  4.1729      0.035    119.395      0.000       4.104       4.241
# Category__TOOLS                   3.9989      0.021    186.673      0.000       3.957       4.041
# Category__TRAVEL_AND_LOCAL        4.0154      0.043     93.411      0.000       3.931       4.100
# Category__VIDEO_PLAYERS           4.0047      0.050     80.195      0.000       3.907       4.103
# Category__WEATHER                 4.2257      0.075     56.289      0.000       4.079       4.373
# ==============================================================================
# Omnibus:                     2681.821   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11535.097
# Skew:                          -1.660   Prob(JB):                         0.00
# Kurtosis:                       7.982   Cond. No.                     7.49e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.49e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Covertendo Type
tp = dummify(cat, "Type")
tp_ = dummify(data, "Type")

# %%
#Separando a coluna que será a saída
quants = quantitativas.copy()
quants.remove('Rating')

# %%
#Adicionando 2 colunas a mais no Data Frame
quant.extend(['Type__Free','Type__Paid'])

# %%
#Adicionando as colunas categóricas da coluna "Type" na regressão
results2 = regress(tp.loc[:, quant], tp.Rating)
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     8.698
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):           5.40e-46
# Time:                        18:42:48   Log-Likelihood:                -6106.8
# No. Observations:                7723   AIC:                         1.229e+04
# Df Residuals:                    7685   BIC:                         1.255e+04
# Df Model:                          37
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Reviews                        1.751e-08   4.29e-09      4.085      0.000    9.11e-09    2.59e-08
# Size                           1.091e-09   2.99e-10      3.654      0.000    5.06e-10    1.68e-09
# Installs                       6.135e-11   1.57e-10      0.392      0.695   -2.46e-10    3.69e-10
# Price                            -0.0009      0.000     -2.363      0.018      -0.002      -0.000
# Category__ART_AND_DESIGN          0.4431      0.069      6.446      0.000       0.308       0.578
# Category__AUTO_AND_VEHICLES       0.2053      0.066      3.109      0.002       0.076       0.335
# Category__BEAUTY                  0.3564      0.086      4.152      0.000       0.188       0.525
# Category__BOOKS_AND_REFERENCE     0.3809      0.044      8.629      0.000       0.294       0.467
# Category__BUSINESS                0.1809      0.034      5.286      0.000       0.114       0.248
# Category__COMICS                  0.1975      0.075      2.643      0.008       0.051       0.344
# Category__COMMUNICATION           0.1516      0.037      4.110      0.000       0.079       0.224
# Category__DATING                  0.0178      0.040      0.441      0.659      -0.061       0.097
# Category__EDUCATION               0.4415      0.050      8.782      0.000       0.343       0.540
# Category__ENTERTAINMENT           0.1998      0.055      3.603      0.000       0.091       0.308
# Category__EVENTS                  0.5446      0.085      6.429      0.000       0.379       0.711
# Category__FAMILY                  0.2278      0.016     14.266      0.000       0.197       0.259
# Category__FINANCE                 0.1756      0.033      5.299      0.000       0.111       0.241
# Category__FOOD_AND_DRINK          0.1506      0.057      2.626      0.009       0.038       0.263
# Category__GAME                    0.2682      0.021     13.002      0.000       0.228       0.309
# Category__HEALTH_AND_FITNESS      0.2745      0.036      7.648      0.000       0.204       0.345
# Category__HOUSE_AND_HOME          0.2243      0.070      3.206      0.001       0.087       0.361
# Category__LIBRARIES_AND_DEMO      0.2722      0.067      4.058      0.000       0.141       0.404
# Category__LIFESTYLE               0.1582      0.032      4.897      0.000       0.095       0.221
# Category__MAPS_AND_NAVIGATION     0.0715      0.054      1.324      0.186      -0.034       0.177
# Category__MEDICAL                 0.2241      0.030      7.379      0.000       0.165       0.284
# Category__NEWS_AND_MAGAZINES      0.2073      0.041      5.051      0.000       0.127       0.288
# Category__PARENTING               0.4032      0.079      5.118      0.000       0.249       0.558
# Category__PERSONALIZATION         0.3684      0.033     11.315      0.000       0.305       0.432
# Category__PHOTOGRAPHY             0.1972      0.035      5.652      0.000       0.129       0.266
# Category__PRODUCTIVITY            0.2018      0.035      5.767      0.000       0.133       0.270
# Category__SHOPPING                0.2846      0.040      7.154      0.000       0.207       0.363
# Category__SOCIAL                  0.3130      0.040      7.827      0.000       0.235       0.391
# Category__SPORTS                  0.2459      0.034      7.182      0.000       0.179       0.313
# Category__TOOLS                   0.0719      0.023      3.192      0.001       0.028       0.116
# Category__TRAVEL_AND_LOCAL        0.0926      0.042      2.205      0.027       0.010       0.175
# Category__VIDEO_PLAYERS           0.0848      0.049      1.730      0.084      -0.011       0.181
# Category__WEATHER                 0.2957      0.073      4.037      0.000       0.152       0.439
# Type__Free                        3.9185      0.010    385.205      0.000       3.899       3.938
# Type__Paid                        4.0143      0.025    163.326      0.000       3.966       4.062
# ==============================================================================
# Omnibus:                     2695.262   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11671.991
# Skew:                          -1.667   Prob(JB):                         0.00
# Kurtosis:                       8.016   Cond. No.                     1.32e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.19e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Fazendo a regressão somente com as categóricas da coluna "Type"
results4 = regress(tp_.loc[:, quants], tp_.Rating)
results4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     1903.
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):               0.00
# Time:                        18:42:48   Log-Likelihood:                -19409.
# No. Observations:                7723   AIC:                         3.883e+04
# Df Residuals:                    7719   BIC:                         3.885e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Reviews     -1.39e-07   2.37e-08     -5.863      0.000   -1.86e-07   -9.26e-08
# Size        9.065e-08   1.08e-09     83.803      0.000    8.85e-08    9.28e-08
# Installs    3.943e-09   8.68e-10      4.540      0.000    2.24e-09    5.64e-09
# Price          0.0103      0.002      5.276      0.000       0.006       0.014
# ==============================================================================
# Omnibus:                     1439.144   Durbin-Watson:                   0.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2401.111
# Skew:                          -1.258   Prob(JB):                         0.00
# Kurtosis:                       4.063   Cond. No.                     2.97e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Covertendo Content Rating
df = dummify(tp, "Content Rating")

# %%
#Adicionando 6 colunas a mais no Data Frame
quant.extend(['Content Rating__Adults only 18+', 'Content Rating__Everyone','Content Rating__Everyone 10+', 'Content Rating__Mature 17+',
       'Content Rating__Teen', 'Content Rating__Unrated'])

# %%
#Refazendo a regressao após adicionar todas as categóricas que foram transformadas em quant
results3 = regress(df.loc[:, quant], data.Rating)
results3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     7.711
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):           4.38e-44
# Time:                        18:42:49   Log-Likelihood:                -6105.7
# No. Observations:                7723   AIC:                         1.230e+04
# Df Residuals:                    7680   BIC:                         1.260e+04
# Df Model:                          42
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Reviews                          1.753e-08   4.33e-09      4.051      0.000    9.05e-09     2.6e-08
# Size                             1.077e-09   3.01e-10      3.582      0.000    4.87e-10    1.67e-09
# Installs                         5.861e-11   1.57e-10      0.374      0.709   -2.49e-10    3.66e-10
# Price                              -0.0009      0.000     -2.367      0.018      -0.002      -0.000
# Category__ART_AND_DESIGN            0.3893      0.069      5.645      0.000       0.254       0.525
# Category__AUTO_AND_VEHICLES         0.1523      0.066      2.297      0.022       0.022       0.282
# Category__BEAUTY                    0.3032      0.086      3.526      0.000       0.135       0.472
# Category__BOOKS_AND_REFERENCE       0.3273      0.044      7.359      0.000       0.240       0.414
# Category__BUSINESS                  0.1279      0.035      3.680      0.000       0.060       0.196
# Category__COMICS                    0.1327      0.075      1.764      0.078      -0.015       0.280
# Category__COMMUNICATION             0.0977      0.037      2.622      0.009       0.025       0.171
# Category__DATING                   -0.0193      0.052     -0.375      0.707      -0.120       0.082
# Category__EDUCATION                 0.3884      0.051      7.677      0.000       0.289       0.488
# Category__ENTERTAINMENT             0.1382      0.057      2.444      0.015       0.027       0.249
# Category__EVENTS                    0.4894      0.085      5.767      0.000       0.323       0.656
# Category__FAMILY                    0.1729      0.017     10.266      0.000       0.140       0.206
# Category__FINANCE                   0.1227      0.034      3.642      0.000       0.057       0.189
# Category__FOOD_AND_DRINK            0.0970      0.058      1.683      0.092      -0.016       0.210
# Category__GAME                      0.2111      0.022      9.720      0.000       0.168       0.254
# Category__HEALTH_AND_FITNESS        0.2214      0.036      6.101      0.000       0.150       0.293
# Category__HOUSE_AND_HOME            0.1710      0.070      2.436      0.015       0.033       0.309
# Category__LIBRARIES_AND_DEMO        0.2195      0.067      3.258      0.001       0.087       0.351
# Category__LIFESTYLE                 0.1045      0.033      3.192      0.001       0.040       0.169
# Category__MAPS_AND_NAVIGATION       0.0186      0.054      0.342      0.732      -0.088       0.125
# Category__MEDICAL                   0.1713      0.031      5.541      0.000       0.111       0.232
# Category__NEWS_AND_MAGAZINES        0.1511      0.042      3.617      0.000       0.069       0.233
# Category__PARENTING                 0.3506      0.079      4.439      0.000       0.196       0.505
# Category__PERSONALIZATION           0.3146      0.033      9.534      0.000       0.250       0.379
# Category__PHOTOGRAPHY               0.1440      0.035      4.076      0.000       0.075       0.213
# Category__PRODUCTIVITY              0.1490      0.035      4.198      0.000       0.079       0.219
# Category__SHOPPING                  0.2296      0.040      5.720      0.000       0.151       0.308
# Category__SOCIAL                    0.2567      0.041      6.213      0.000       0.176       0.338
# Category__SPORTS                    0.1907      0.035      5.509      0.000       0.123       0.259
# Category__TOOLS                     0.0188      0.023      0.809      0.418      -0.027       0.064
# Category__TRAVEL_AND_LOCAL          0.0400      0.042      0.941      0.347      -0.043       0.123
# Category__VIDEO_PLAYERS             0.0303      0.049      0.614      0.539      -0.066       0.127
# Category__WEATHER                   0.2421      0.073      3.295      0.001       0.098       0.386
# Type__Free                          3.0293      0.079     38.292      0.000       2.874       3.184
# Type__Paid                          3.1254      0.082     38.303      0.000       2.965       3.285
# Content Rating__Adults only 18+     1.3336      0.339      3.932      0.000       0.669       1.999
# Content Rating__Everyone            0.9422      0.084     11.234      0.000       0.778       1.107
# Content Rating__Everyone 10+        0.9499      0.088     10.800      0.000       0.777       1.122
# Content Rating__Mature 17+          0.9245      0.089     10.362      0.000       0.750       1.099
# Content Rating__Teen                0.9593      0.085     11.253      0.000       0.792       1.126
# Content Rating__Unrated             1.0451      0.470      2.223      0.026       0.124       1.967
# ==============================================================================
# Omnibus:                     2692.768   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11652.387
# Skew:                          -1.666   Prob(JB):                         0.00
# Kurtosis:                       8.011   Cond. No.                     1.32e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.19e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Removendo as colunas que possuíram um p-value alto, a fim de tentar melhorar nossa regressão 
quant.remove('Installs')
quant.remove('Category__DATING')
quant.remove('Category__MAPS_AND_NAVIGATION')
quant.remove('Category__TOOLS')

results = regress(df.loc[:, quant], data.Rating)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     8.291
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):           2.40e-45
# Time:                        18:42:49   Log-Likelihood:                -6106.0
# No. Observations:                7723   AIC:                         1.229e+04
# Df Residuals:                    7683   BIC:                         1.257e+04
# Df Model:                          39
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Reviews                           1.85e-08   3.45e-09      5.356      0.000    1.17e-08    2.53e-08
# Size                             1.077e-09      3e-10      3.587      0.000    4.88e-10    1.67e-09
# Price                              -0.0009      0.000     -2.371      0.018      -0.002      -0.000
# Category__ART_AND_DESIGN            0.3753      0.073      5.164      0.000       0.233       0.518
# Category__AUTO_AND_VEHICLES         0.1381      0.070      1.972      0.049       0.001       0.275
# Category__BEAUTY                    0.2895      0.090      3.221      0.001       0.113       0.466
# Category__BOOKS_AND_REFERENCE       0.3134      0.048      6.490      0.000       0.219       0.408
# Category__BUSINESS                  0.1138      0.039      2.926      0.003       0.038       0.190
# Category__COMICS                    0.1208      0.079      1.526      0.127      -0.034       0.276
# Category__COMMUNICATION             0.0848      0.041      2.058      0.040       0.004       0.166
# Category__EDUCATION                 0.3747      0.054      6.891      0.000       0.268       0.481
# Category__ENTERTAINMENT             0.1263      0.060      2.090      0.037       0.008       0.245
# Category__EVENTS                    0.4754      0.089      5.354      0.000       0.301       0.649
# Category__FAMILY                    0.1594      0.024      6.756      0.000       0.113       0.206
# Category__FINANCE                   0.1085      0.038      2.859      0.004       0.034       0.183
# Category__FOOD_AND_DRINK            0.0830      0.061      1.351      0.177      -0.037       0.203
# Category__GAME                      0.1988      0.028      7.169      0.000       0.144       0.253
# Category__HEALTH_AND_FITNESS        0.2079      0.040      5.136      0.000       0.129       0.287
# Category__HOUSE_AND_HOME            0.1569      0.074      2.122      0.034       0.012       0.302
# Category__LIBRARIES_AND_DEMO        0.2053      0.071      2.891      0.004       0.066       0.344
# Category__LIFESTYLE                 0.0907      0.037      2.450      0.014       0.018       0.163
# Category__MEDICAL                   0.1574      0.035      4.454      0.000       0.088       0.227
# Category__NEWS_AND_MAGAZINES        0.1394      0.046      3.057      0.002       0.050       0.229
# Category__PARENTING                 0.3367      0.083      4.067      0.000       0.174       0.499
# Category__PERSONALIZATION           0.3010      0.037      8.097      0.000       0.228       0.374
# Category__PHOTOGRAPHY               0.1304      0.039      3.306      0.001       0.053       0.208
# Category__PRODUCTIVITY              0.1353      0.040      3.423      0.001       0.058       0.213
# Category__SHOPPING                  0.2161      0.044      4.894      0.000       0.130       0.303
# Category__SOCIAL                    0.2461      0.045      5.486      0.000       0.158       0.334
# Category__SPORTS                    0.1767      0.039      4.519      0.000       0.100       0.253
# Category__TRAVEL_AND_LOCAL          0.0259      0.046      0.558      0.577      -0.065       0.117
# Category__VIDEO_PLAYERS             0.0167      0.053      0.315      0.753      -0.087       0.121
# Category__WEATHER                   0.2280      0.077      2.954      0.003       0.077       0.379
# Type__Free                          3.0381      0.083     36.537      0.000       2.875       3.201
# Type__Paid                          3.1344      0.086     36.654      0.000       2.967       3.302
# Content Rating__Adults only 18+     1.3377      0.340      3.937      0.000       0.672       2.004
# Content Rating__Everyone            0.9476      0.083     11.443      0.000       0.785       1.110
# Content Rating__Everyone 10+        0.9540      0.087     10.958      0.000       0.783       1.125
# Content Rating__Mature 17+          0.9147      0.086     10.656      0.000       0.746       1.083
# Content Rating__Teen                0.9634      0.084     11.423      0.000       0.798       1.129
# Content Rating__Unrated             1.0550      0.471      2.242      0.025       0.132       1.978
# ==============================================================================
# Omnibus:                     2695.763   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11673.719
# Skew:                          -1.667   Prob(JB):                         0.00
# Kurtosis:                       8.016   Cond. No.                     1.04e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.66e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# Visualizamos que com as colunas qualitativas, nossa regressão não apresentou um nível de confiança alto, então tentaremos modificar a saída para ver se possuímos assim uma regressão que de para confiar, ou seja, uma regressão que possui um R quadrado maior

# %% [markdown]
# ### Etapa 4: Install como saída

# %% [markdown]
# #### 4.1: Regressão Linear somente com as colunas quantitativas

# %%
#Declarando Quantitativas
quantitativas = ['Rating', 'Reviews', 'Size', 'Installs', 'Price']

# %%
#Separando a coluna que será a saída
quant_ = quantitativas.copy()
quant_.remove('Installs')

# %%
#Fazendo a regressão com a constante
resultado = regress_cp(data_.loc[:, quant_], data_.Installs)
resultado.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Installs   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     1246.
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):               0.00
# Time:                        18:42:51   Log-Likelihood:            -1.4597e+05
# No. Observations:                7723   AIC:                         2.919e+05
# Df Residuals:                    7718   BIC:                         2.920e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.171e+06   3.45e+06      0.629      0.530    -4.6e+06    8.94e+06
# Rating      1.676e+05   8.22e+05      0.204      0.838   -1.44e+06    1.78e+06
# Reviews       16.7632      0.246     68.014      0.000      16.280      17.246
# Size           0.0272      0.020      1.386      0.166      -0.011       0.066
# Price      -1.192e+04   2.56e+04     -0.466      0.641   -6.21e+04    3.82e+04
# ==============================================================================
# Omnibus:                    12546.497   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         29248589.092
# Skew:                          10.163   Prob(JB):                         0.00
# Kurtosis:                     303.799   Cond. No.                     2.62e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.62e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Analisando graficamente
probplot(resultado.resid, dist="norm", plot=plt);

# %% [markdown]
# O gráfico acima nos permite afirmar que os resíduos dessa regressão linear seguem uma distribuição normal.

# %% [markdown]
# #### 4.2: Tirando a constante da regressão linear

# %%
#Fazendo a regressão sem a constante
resultado1 = regress(data_.loc[:, quant_], data_.Installs)
resultado1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Installs   R-squared:                      -6.726
# Model:                            OLS   Adj. R-squared:                 -6.730
# Method:                 Least Squares   F-statistic:                    -1680.
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):               1.00
# Time:                        18:42:52   Log-Likelihood:            -1.4597e+05
# No. Observations:                7723   AIC:                         2.919e+05
# Df Residuals:                    7719   BIC:                         2.920e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Rating      6.756e+05   1.49e+05      4.540      0.000    3.84e+05    9.67e+05
# Reviews       16.7522      0.246     68.143      0.000      16.270      17.234
# Size           0.0279      0.020      1.426      0.154      -0.010       0.066
# Price      -1.143e+04   2.56e+04     -0.447      0.655   -6.15e+04    3.87e+04
# ==============================================================================
# Omnibus:                    12549.543   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         29258457.434
# Skew:                          10.169   Prob(JB):                         0.00
# Kurtosis:                     303.849   Cond. No.                     1.10e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Analisando graficamente
probplot(resultado1.resid, dist="norm", plot=plt);

# %% [markdown]
# Notamos que quando tiramos beta0, a regressão linear apresentou um R ao quadrado negativo, isso ocorreu devido ao fato de a coluna "Install" apresentar uma variação grande em seus números, ou seja, a ordem de grandeza varia muito. Assim, passamos essa coluna de normal para logarítmica a fim de deixar sua distribuição mais linear.

# %%
data_["logInstalls"] = np.log(data_.Installs)

# %%
#Fazendo a regressão
resultado_log = regress(data_.loc[:, quant_], data_.logInstalls)
resultado_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            logInstalls   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                 2.037e+04
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):               0.00
# Time:                        18:42:53   Log-Likelihood:                -20843.
# No. Observations:                7723   AIC:                         4.169e+04
# Df Residuals:                    7719   BIC:                         4.172e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Rating         2.4717      0.014    180.606      0.000       2.445       2.499
# Reviews     3.772e-07   2.26e-08     16.680      0.000    3.33e-07    4.21e-07
# Size        4.695e-08    1.8e-09     26.090      0.000    4.34e-08    5.05e-08
# Price         -0.0082      0.002     -3.500      0.000      -0.013      -0.004
# ==============================================================================
# Omnibus:                      512.805   Durbin-Watson:                   1.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              618.992
# Skew:                          -0.672   Prob(JB):                    3.87e-135
# Kurtosis:                       3.342   Cond. No.                     1.10e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Analisando graficamente
probplot(resultado_log.resid, dist="norm", plot=plt);

# %% [markdown]
# Quando a coluna "Install" foi passada para logarítimica notamos que ela se aproximou muito da distribuição normal e apresentou um R ao quadrado muito confiante de 91.3%

# %% [markdown]
# ## Etapa 5 - Predição usando Install como saída

# %%
train, test = train_test_split(data_, test_size=0.2)

# %%
#Fazendo a regressão
resultado_final = regress(train.loc[:, quant_], train.logInstalls)
resultado_final.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            logInstalls   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                 1.620e+04
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):               0.00
# Time:                        18:43:33   Log-Likelihood:                -16686.
# No. Observations:                6178   AIC:                         3.338e+04
# Df Residuals:                    6174   BIC:                         3.341e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Rating         2.4716      0.015    161.658      0.000       2.442       2.502
# Reviews     3.596e-07   2.45e-08     14.665      0.000    3.12e-07    4.08e-07
# Size        4.659e-08   2.01e-09     23.180      0.000    4.26e-08    5.05e-08
# Price         -0.0087      0.003     -3.047      0.002      -0.014      -0.003
# ==============================================================================
# Omnibus:                      410.165   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              494.545
# Skew:                          -0.672   Prob(JB):                    4.08e-108
# Kurtosis:                       3.338   Cond. No.                     1.09e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
predicao = resultado_final.predict(test.loc[:, quant_])

# %%
lista_p = list(predicao)
original = list(test.logInstalls)
e = []
for t in range(len(lista_p)):
    e.append(math.sqrt((lista_p[t]-original[t])**2))

# %%
media_e = sum(e)/len(e)
media_o = sum(original)/len(original)

# %%
erro = media_e/media_o

# %%
acerto = (1 - erro)*100

# %%
print("O acerto da nossa predição foi de {:.2f}%".format(acerto))
# Out:
# O acerto da nossa predição foi de 75.51%

# %% [markdown]
# ## Etapa 6 - Conclusão

# %% [markdown]
# O objetivo do nosso projeto era achar os valores de rating de aplicativos utilizando regressão linear e dados oferecidos pelo dataset como váriaveis. Entretanto, mudamos o direcionamento do nosso projeto pois nós como grupo entramos em consenso que as principais váriaveis utilizadas: reviews, size, installs e price, até certo ponto são capazes de responder rating, o que pode ser visto no passo 3.2 onde r² = 49%, mas após transformar as qualitativass em quantitavas, passso 3.3, nosso r² = 04%.
#
# Assim iniciamos a Etapa 4 utilizando Install como saída da nossa regressão. Após manipularmos devidamente as variáveis, obtivemos um r² = 91%, o que nos garante 91% de acerto, para termos certeza de que é confiável realizamos um teste na Etapa 5. No teste, sorteamos 80% dos dados para montarmos a regressão linear que resulta num r² = 91%. A partir do modelo obtido, a função predict() foi utilizada, para com os dados restantes; 20%, o modelo fosse testado e validado.
#
# Todos os erros foram obtidos, e depois a sua média foi calculada. Relacionando essa informação com a média dos Installs originais, 20%, obteve-se uma taxa de acerto: 75%.

# %% [markdown]
# ## Etapa 7 - Divi

# %% [markdown]
# Arthur: responsável por fazer as regressões lineares, tranformar as colunas qualitativas em quantitativas.
#
# Zanetti: responsável, primeiramente, pela organização de dados do antigo dataset UFC, fazer algumas funções para limpar as colunas categóricas, fazer o código da predição e parte da conclusão.
#
# Roger: responsável por fazer funções para limpar o dataset, conteúdo que ajudou na regressão linear (Prob(Omnibus) baixo não pode confiar nos p-values) e conclusão.
